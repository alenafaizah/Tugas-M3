# %%
nama=(input("Nama Pelanggan: "))
alamat=(input('Alamat: '))
usia=int(input('Usia: '))
# Out:
# Nama Pelanggan:  Alena
# Alamat:  Surabaya
# Usia:  18

# %%
modal=float(input("Modal Awal: "))
keuntungan=0.2*modal
print(f'Target Keuntungan: {keuntungan}')
# Out:
# Modal Awal:  250000
# Target Keuntungan: 50000.0

# %%
hari=input("Hari: ")
bulan=(input("Bulan: "))
tahun=(input("Tahun: "))
print(hari, bulan, tahun, sep="-")
# Out:
# Hari:  Kamis
# Bulan:  September
# Tahun:  2026
# Kamis-September-2026

# %%
print('ID Produk Harga\n------------')

print('ID Produk Harga')
print('-'*15)

#kak ini 2 opsi, outputnya sama aja
# Out:
# ID Produk Harga
# ------------
# ID Produk Harga
# ---------------

# %%
produk="Kalkulator Saintifik"
harga=float(245000.5)
print(f'Harga {produk} adalah Rp {harga:,.2f}')
# Out:
# Harga Kalkulator Saintifik adalah Rp 245,000.50

# %%
(input("Nama Lengkap: "))
usia=int(input("Usia: "))
kontak=(input("Kontak: "))
alamat=(input("Alamat Asal: "))
kampus=(input("Kampus: "))
fakultas=(input("Fakultas: "))
departemen=(input("Departemen: "))
nrp=(input("NRP: "))
angkatan=int(input("Angkatan: "))
sks=int(input("SKS: "))
matkul=(input("Matkul: "))
target_karier=(input("Targer Karier (Dream Job)"))

print('='*90)
print('{0:<2}{1:^86}{2:>2}'.format('|', 'DASBOR PROFIL MAHASISWA & RENCANA KARIER', '|'))
print('='*90)
print('{0:<2}{1:<20}{2:>68}'.format('|','INFORMASI PERSONAL','|'))
print('-'*90)
print('{0:<2}{1:<18}{2:<2}{3:<66}{4:>2}'.format('|','Nama Lengkap',':', nama,'|'))
print('{0:<2}{1:<18}{2:<2}{3:<3}{4:<5}{5:^3}{6:<55}{7:>2}'.format('|','Usia & Kontak', ':', usia,'Tahun','|', kontak, '|'))
print('{0:<2}{1:<18}{2:<2}{3:<66}{4:>2}'.format('|','Alamat Asal',':',alamat,'|'))
print('-'*90)
print('{0:<2}{1:<86}{2:>2}'.format('|','INFORMASI AKADEMIK','|'))
print('-'*90)
print('{0:<2}{1:<18}{2:<2}{3:<66}{4:>2}'.format('|','Kampus',':',kampus,'|'))
print('{0:<2}{1:<18}{2:<2}{3:<6}{4:^3}{5:<57}{6:>2}'.format('|','Fakultas / Dept',':',fakultas,'/',departemen,'|'))
print('{0:<2}{1:<18}{2:<2}{3:<13}{4:^3}{5:<50}{6:>2}'.format('|','NRP / Angkatan',':',nrp,'/',angkatan,'|'))
print('{0:<2}{1:<18}{2:<2}{3:<3}{4:<3}{5:^3}{6:<57}{7:>2}'.format('|','SKS & Matkul',':',sks,'SKS','|',matkul,'|'))
print('='*90)
print('{0:<2}{1:^86}{2:>2}'.format('|','TARGET KARIER (DREAM JOB)','|'))
print('{0:<2}{1:^86}{2:>2}'.format('|',target_karier,'|'))
print('='*90)
# Out:
# Nama Lengkap:  Naila Dzulfa
# Usia:  18
# Kontak:  0812345678
# Alamat Asal:  Mulyosari
# Kampus:  Institut Teknologi Sepuluh Nopember
# Fakultas:  Vokasi
# Departemen:  Statistika Bisnis
# NRP:  2043251046
# Angkatan:  2025
# SKS:  36
# Matkul:  Algoritma dan Pemrograman
# Targer Karier (Dream Job) ORANG SAKSES
# ...
# |                        DASBOR PROFIL MAHASISWA & RENCANA KARIER                        |
# ...
# | INFORMASI PERSONAL                                                                     |
# ------------------------------------------------------------------------------------------
# | Nama Lengkap      : Alena                                                              |
# | Usia & Kontak     : 18 Tahun | 0812345678                                              |
# | Alamat Asal       : Mulyosari                                                          |
# ------------------------------------------------------------------------------------------
# ...
